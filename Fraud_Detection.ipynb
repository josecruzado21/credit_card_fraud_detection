# %% [markdown]
# # Payment Fraud Detection

# %% [markdown]
# The data used in the following notebook was obtained from Kaggle (Dal Pozzolo et al 2015). Link to the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud/data
#
# According to the dictionary, to protect the identity, the variables in the data set are the consequence of a dimensionality reduction process (PCA). The time variable represent the number of seconds elapsed between the transaction and the first transaction in the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#As we will deploy our model in Amazon SageMaker, it is necessary to import the packages for that task
import sagemaker
import boto3
from sagemaker import get_execution_role #With get_execution_role we can obtain the role/permissions of the session

# %%
client = boto3.client('sagemaker-runtime')

# %%
sagemaker_role=sagemaker.get_execution_role()
sagemaker_session=sagemaker.Session()
bucket=sagemaker_session.default_bucket()
print(sagemaker_role)
print(sagemaker_session)
print(bucket)
# Out:
# arn:aws:iam::095482984955:role/service-role/AmazonSageMaker-ExecutionRole-20210117T214625
# <sagemaker.session.Session object at 0x7f24565fe358>
# sagemaker-us-east-1-095482984955

# %%
data_fraud=pd.read_csv('creditcard.csv')

# %%
print('Data Points: {}'.format(data_fraud.shape[0]))
print('Variables: {}'.format(data_fraud.shape[1]))
# Out:
# Data Points: 284807
# Variables: 31

# %%
data_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#To analyze the class imbalance
def percentage_fraudulent(df):
    '''Calculates the proportion of data points that are labeled as 1 (fraudulent).
       Parameter: the dataframe that has a 'Class' column
       Return: The proportion of fraudulent datapoints
    '''
    return df['Class'].mean()

# %%
print('Percentage of fraudulent transaction in the dataset: {}%'.format(percentage_fraudulent(data_fraud)*100))
# Out:
# Percentage of fraudulent transaction in the dataset: 0.1727485630620034%

# %% [markdown]
# Only 0.17% of all the dataset are fraudulent transaction. The dataset is extremely imbalanced and we should adress the imbalance before estimating a model, otherwise most algorithms will make almost all predictions 0

# %%
from sklearn.model_selection import train_test_split
train_X,test_x,train_y,test_y=train_test_split(data_fraud.drop('Class',axis=1),data_fraud['Class'],random_state=1,train_size=0.7)

# %% [markdown]
# To estimate a logistic regression with SageMaker, we should use the bult-in LinearLearner algotirhm

# %%
from sagemaker import LinearLearner

prefix='fraud_detection'
output_path='s3://{}/{}'.format(bucket, prefix)

linear_learner=LinearLearner(role=sagemaker_role,
                            instance_count=1,
                            instance_type='ml.c4.xlarge',
                            predictor_type='binary_classifier',
                            output_path=output_path,
                            sagemaker_session=sagemaker_session)

# %%
data_record=linear_learner.record_set(train_X.to_numpy('float32'),labels=train_y.to_numpy('float32'))

# %%
data_record
# Out:
# (<class 'sagemaker.amazon.amazon_estimator.RecordSet'>, {'s3_data': 's3://sagemaker-us-east-1-095482984955/sagemaker-record-sets/LinearLearner-2021-02-23-02-27-54-742/.amazon.manifest', 'feature_dim': 30, 'num_records': 199364, 's3_data_type': 'ManifestFile', 'channel': 'train'})

# %%
# %%time
linear_learner.fit(data_record)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-23 02:28:01 Starting - Starting the training job...
# 2021-02-23 02:28:25 Starting - Launching requested ML instancesProfilerReport-1614047281: InProgress
# .........
# 2021-02-23 02:29:46 Starting - Preparing the instances for training.........
# 2021-02-23 02:31:29 Downloading - Downloading input data
# 2021-02-23 02:31:29 Training - Downloading the training image...
# 2021-02-23 02:31:49 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/23/
, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1614047614.80354, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1614047516.487986}
#
#
# 2021-02-23 02:33:49 Uploading - Uploading generated training model
# 2021-02-23 02:33:49 Completed - Training job completed
# Training seconds: 151
# Billable seconds: 151
# CPU times: user 874 ms, sys: 54.2 ms, total: 928 ms
# Wall time: 6min 14s

# %% [markdown]
# Once the model is trained, we shoul deploy it so we can make prediction using test data

# %%
# %%time
predictor=linear_learner.deploy(initial_instance_count=1,
                     instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------------!CPU times: user 401 ms, sys: 13.9 ms, total: 415 ms
# Wall time: 11min 35s

# %%
test_record=test_x.to_numpy('float32')
print(predictor.predict(test_record[0]))
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0002751190622802824
#     }
#   }
# }
# ]

# %%
list_predictions=[predictor.predict(batch) for batch in np.array_split(test_record,100)]

# %%
np.concatenate([[i.label['predicted_label'].float32_tensor.values[0] for i in chunks] for chunks in list_predictions])
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
list_predictions[0][1]
# Out:
# label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.00016928077093325555
#     }
#   }
# }

# %%
predictor.predict(test_record[0:2])[0].label['predicted_label'].float32_tensor.values[0]
# Out:
# 0.0

# %%
def evaluation_metrics(test_input,test_label,predictor):
    list_predictions=[predictor.predict(batch) for batch in np.array_split(test_input,100)]
    predictions_test=np.concatenate([[i.label['predicted_label'].float32_tensor.values[0] for i in chunks] for chunks in list_predictions])
    
    tp = np.logical_and(test_label, predictions_test).sum()
    fp = np.logical_and(1-test_label, predictions_test).sum()
    tn = np.logical_and(1-test_label, 1-predictions_test).sum()
    fn = np.logical_and(test_label, 1-predictions_test).sum()
    
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
           
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %%
evaluation_metrics(test_record,test_y,predictor)
# Out:
# {'TP': 99,
#  'FP': 26,
#  'FN': 36,
#  'TN': 85282,
#  'Precision': 0.792,
#  'Recall': 0.7333333333333333,
#  'Accuracy': 0.9992743700478681}

# %%
boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'ResponseMetadata': {'RequestId': 'd2566912-518d-4166-bf23-45fb1153a09a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd2566912-518d-4166-bf23-45fb1153a09a',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Tue, 23 Feb 2021 02:46:17 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # As the task is to predict fraudulent transactions, it is most important the recall than accuracy as we would like to avoi false negatives (transactions labeled as legitimate when they were actually fraudulent)

# %% [markdown]
# Sagemaker has a parameter for the Linear Learner algorithms that allow to indicate the metric to consider the best performing model. According to the documentation, when predictor_type is set to binary_classifier, it is the model evaluation criteria for the validation set (or training set in case validation set is not provided).

# %%
linear_recall = LinearLearner(role=sagemaker_role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall',
                              target_recall=0.9)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
"Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614049823.183807}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013148174486567627, "sum": 0.013148174486567627, "min": 0.013148174486567627}}, "EndTime": 1614049823.183896, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614049823.183878}
#
# [02/23/2021 03:10:23 INFO 139715668854592] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0168833395752
# [02/23/2021 03:10:23 INFO 139715668854592] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906
# [02/23/2021 03:10:23 INFO 139715668854592] Epoch 1: Loss improved. Updating best model
# [02/23/2021 03:10:23 INFO 139715668854592] Saving model for epoch: 1
# [02/23/2021 03:10:23 INFO 139715668854592] Saved checkpoint to "/tmp/tmpNz5zR_/mx-mod-0000.params"
# [02/23/2021 03:10:23 INFO 139715668854592] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1614049823.191442, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614049816.67305}
#
# [02/23/2021 03:10:23 INFO 139715668854592] #throughput_metric: host=algo-1, train throughput=30584.3834498 records/second
# [2021-02-23 03:10:28.983] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 5790, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010249469512671083, "sum": 0.010249469512671083, "min": 0.010249469512671083}}, "EndTime": 1614049828.983893, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.983794}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008671593309047832, "sum": 0.008671593309047832, "min": 0.008671593309047832}}, "EndTime": 1614049828.984, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.983979}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010244108916527063, "sum": 0.010244108916527063, "min": 0.010244108916527063}}, "EndTime": 1614049828.984075, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00867205645930228, "sum": 0.00867205645930228, "min": 0.00867205645930228}}, "EndTime": 1614049828.984146, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984127}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004918119081076066, "sum": 0.004918119081076066, "min": 0.004918119081076066}}, "EndTime": 1614049828.984213, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984195}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005651303291320801, "sum": 0.005651303291320801, "min": 0.005651303291320801}}, "EndTime": 1614049828.984277, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.98426}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0049273479259643125, "sum": 0.0049273479259643125, "min": 0.0049273479259643125}}, "EndTime": 1614049828.984342, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984324}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005490868361226878, "sum": 0.005490868361226878, "min": 0.005490868361226878}}, "EndTime": 1614049828.984413, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984394}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010515944255656334, "sum": 0.010515944255656334, "min": 0.010515944255656334}}, "EndTime": 1614049828.98448, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984462}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009003221483086821, "sum": 0.009003221483086821, "min": 0.009003221483086821}}, "EndTime": 1614049828.984555, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984536}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010521823832737141, "sum": 0.010521823832737141, "min": 0.010521823832737141}}, "EndTime": 1614049828.984627, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984609}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008999888767549142, "sum": 0.008999888767549142, "min": 0.008999888767549142}}, "EndTime": 1614049828.984707, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984689}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005593623910117988, "sum": 0.005593623910117988, "min": 0.005593623910117988}}, "EndTime": 1614049828.984765, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984749}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005721277174338624, "sum": 0.005721277174338624, "min": 0.005721277174338624}}, "EndTime": 1614049828.984816, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984806}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005546630558656089, "sum": 0.005546630558656089, "min": 0.005546630558656089}}, "EndTime": 1614049828.984846, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984839}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005712993024581641, "sum": 0.005712993024581641, "min": 0.005712993024581641}}, "EndTime": 1614049828.984893, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984879}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015533093172102119, "sum": 0.015533093172102119, "min": 0.015533093172102119}}, "EndTime": 1614049828.98494, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984926}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0142904183541111, "sum": 0.0142904183541111, "min": 0.0142904183541111}}, "EndTime": 1614049828.984983, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.984969}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01553408638556399, "sum": 0.01553408638556399, "min": 0.01553408638556399}}, "EndTime": 1614049828.98504, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985024}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014295967495022108, "sum": 0.014295967495022108, "min": 0.014295967495022108}}, "EndTime": 1614049828.985092, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985079}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072144002171617, "sum": 0.012072144002171617, "min": 0.012072144002171617}}, "EndTime": 1614049828.985141, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985131}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0121305170963757, "sum": 0.0121305170963757, "min": 0.0121305170963757}}, "EndTime": 1614049828.98517, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985163}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072037987373583, "sum": 0.012072037987373583, "min": 0.012072037987373583}}, "EndTime": 1614049828.985196, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985189}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012126008991021007, "sum": 0.012126008991021007, "min": 0.012126008991021007}}, "EndTime": 1614049828.985227, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985215}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016575735899671238, "sum": 0.016575735899671238, "min": 0.016575735899671238}}, "EndTime": 1614049828.985282, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985266}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536184029123891, "sum": 0.01536184029123891, "min": 0.01536184029123891}}, "EndTime": 1614049828.98534, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985324}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01657752835451059, "sum": 0.01657752835451059, "min": 0.01657752835451059}}, "EndTime": 1614049828.985398, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985383}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536392712712887, "sum": 0.01536392712712887, "min": 0.01536392712712887}}, "EndTime": 1614049828.985454, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985444}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013144806580327862, "sum": 0.013144806580327862, "min": 0.013144806580327862}}, "EndTime": 1614049828.985499, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985485}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013156182020153832, "sum": 0.013156182020153832, "min": 0.013156182020153832}}, "EndTime": 1614049828.985556, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.98554}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013145586877012972, "sum": 0.013145586877012972, "min": 0.013145586877012972}}, "EndTime": 1614049828.985612, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985597}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01315547815998595, "sum": 0.01315547815998595, "min": 0.01315547815998595}}, "EndTime": 1614049828.985666, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049828.985655}
#
# [02/23/2021 03:10:28 INFO 139715668854592] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0102494695127
# [02/23/2021 03:10:28 INFO 139715668854592] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00491811908108
# [02/23/2021 03:10:28 INFO 139715668854592] Epoch 2: Loss improved. Updating best model
# [02/23/2021 03:10:28 INFO 139715668854592] Saving model for epoch: 2
# [02/23/2021 03:10:28 INFO 139715668854592] Saved checkpoint to "/tmp/tmpXcwixo/mx-mod-0000.params"
# [02/23/2021 03:10:28 INFO 139715668854592] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1614049828.994041, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614049823.192723}
#
# [02/23/2021 03:10:28 INFO 139715668854592] #throughput_metric: host=algo-1, train throughput=34364.5715515 records/second
# [2021-02-23 03:10:34.884] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 5888, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00796071047279703, "sum": 0.00796071047279703, "min": 0.00796071047279703}}, "EndTime": 1614049834.884515, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614049834.884419}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0066089136300973555, "sum": 0.0066089136300973555, "min": 0.0066089136300973555}}, "EndTime": 1614049834.884603, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614049834.884589}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007957086086273194, "sum": 0.007957086086273194, "min": 0.007957086086273194}}, "EndTime": 1614049834.884651, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614049834.88464}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006610484449108642, "sum": 0.006610484449108642, "min": 0.006610484449108642}}, "EndTime": 1614049834.884695, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614049834.884685}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0041351939227113775, "sum": 0.0041351939227113775, "min": 0.0041351939227113775}}, "EndTime": 1614049900.895448, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614049900.895431}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0040303359740044, "sum": 0.0040303359740044, "min": 0.0040303359740044}}, "EndTime": 1614049900.89552, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614049900.8955}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005875211362862707, "sum": 0.005875211362862707, "min": 0.005875211362862707}}, "EndTime": 1614049900.895585, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614049900.
"Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614049900.897108}
#
# [02/23/2021 03:11:40 INFO 139715668854592] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00479624264983
# [02/23/2021 03:11:40 INFO 139715668854592] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.004030335974
# [02/23/2021 03:11:40 INFO 139715668854592] Epoch 14: Loss improved. Updating best model
# [02/23/2021 03:11:40 INFO 139715668854592] Saving model for epoch: 14
# [02/23/2021 03:11:40 INFO 139715668854592] Saved checkpoint to "/tmp/tmpFtdNIU/mx-mod-0000.params"
# [02/23/2021 03:11:40 INFO 139715668854592] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1614049900.903857, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614049895.054702}
#
# [02/23/2021 03:11:40 INFO 139715668854592] #throughput_metric: host=algo-1, train throughput=34083.6507553 records/second
# [02/23/2021 03:11:40 WARNING 139715668854592] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/23/2021 03:11:40 WARNING 139715668854592] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-23 03:11:40.911] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-02-23 03:11:41.532] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 619, "num_examples": 200, "num_bytes": 33493152}
# [2021-02-23 03:11:42.326] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 721, "num_examples": 200, "num_bytes": 33493152}
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('binary_classification_accuracy', 0.9879416544611865)
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('binary_f_1.000', 0.21180327868852458)
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('precision', 0.11994058670627553)
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/23/2021 03:11:42 INFO 139715668854592] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00396091186531
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.987941654461
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.211803278689
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train precision <score>=0.119940586706
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train recall <score>=0.904761904762
# [02/23/2021 03:11:42 INFO 139715668854592] #quality_metric: host=algo-1, train roc_auc_score <score>=0.979089470538
# [02/23/2021 03:11:42 INFO 139715668854592] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/23/2021 03:11:42 INFO 139715668854592] Saved checkpoint to "/tmp/tmpGVyNTF/mx-mod-0000.params"
# [02/23/2021 03:11:42 INFO 139715668854592] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 92498.291015625, "sum": 92498.291015625, "min": 92498.291015625}, "finalize.time": {"count": 1, "max": 1480.2908897399902, "sum": 1480.2908897399902, "min": 1480.2908897399902}, "initialize.time": {"count": 1, "max": 205.66296577453613, "sum": 205.66296577453613, "min": 205.66296577453613}, "check_early_stopping.time": {"count": 15, "max": 0.9357929229736328, "sum": 12.849569320678711, "min": 0.7588863372802734}, "setuptime": {"count": 1, "max": 26.686906814575195, "sum": 26.686906814575195, "min": 26.686906814575195}, "update.time": {"count": 15, "max": 6515.959978103638, "sum": 90469.36440467834, "min": 5465.170860290527}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1614049902.389732, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1614049810.165992}
#
#
# 2021-02-23 03:12:07 Uploading - Uploading generated training model
# 2021-02-23 03:12:07 Completed - Training job completed
# ProfilerReport-1614049599: NoIssuesFound
# Training seconds: 146
# Billable seconds: 146

# %%
predictor_recall=linear_recall.deploy(instance_type='ml.t2.medium',initial_instance_count=1)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# --------------------!

# %%
evaluation_metrics(test_record,test_y,predictor_recall)
# Out:
# {'TP': 115,
#  'FP': 991,
#  'FN': 20,
#  'TN': 84317,
#  'Precision': 0.10397830018083183,
#  'Recall': 0.8518518518518519,
#  'Accuracy': 0.988167550296689}

# %%
boto3.client('sagemaker').delete_endpoint(EndpointName=predictor_recall.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'ResponseMetadata': {'RequestId': '52179924-6753-4fd0-a14d-957a6f290280',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '52179924-6753-4fd0-a14d-957a6f290280',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Tue, 23 Feb 2021 03:27:11 GMT'},
#   'RetryAttempts': 0}}

# %%
linear_balanced = LinearLearner(role=sagemaker_role,
                                train_instance_count=1, 
                                train_instance_type='ml.c4.xlarge',
                                predictor_type='binary_classifier',
                                output_path=output_path,
                                sagemaker_session=sagemaker_session,
                                epochs=15,
                                binary_classifier_model_selection_criteria='precision_at_target_recall',
                                target_recall=0.9,
                                positive_example_weight_mult='balanced')
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
linear_balanced.fit(data_record)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-23 03:28:27 Starting - Starting the training job...
# 2021-02-23 03:28:50 Starting - Launching requested ML instancesProfilerReport-1614050906: InProgress
# ......
# 2021-02-23 03:29:51 Starting - Preparing the instances for training.........
# 2021-02-23 03:31:14 Downloading - Downloading input data
# 2021-02-23 03:31:14 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/23/2021 03:31:38 INFO 140417266886464] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/23/2021 03:31:38 INFO 140417266886464] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [02/23/2021 03:31:39 INFO 140417266886464] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [02/23/2021 03:31:39 WARNING 140417266886464] Loggers have already been setup.
# Process 1 is a worker.
# [02/23/2021 03:31:39 INFO 140417266886464] Using default worker.
# [02/23/2021 03:31:39 INFO 140417266886464] Checkpoint loading and saving are disabled.
# [2021-02-23 03:31:39.240] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1, "num_bytes": 168000}
# [02/23/2021 03:31:39 INFO 140417266886464] Create Store: local
# [2021-02-23 03:31:39.332] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 90, "num_examples": 11, "num_bytes": 1848000}
# [02/23/2021 03:31:39 INFO 140417266886464] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb511d3bd50>
# [02/23/2021 03:31:39 INFO 140417266886464] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/23/2021 03:31:39 INFO 140417266886464] nvidia-smi took: 0.0252239704132 secs to identify 0 gpus
# [02/23/2021 03:31:39 INFO 140417266886464] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1614051099.542016, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1614051099.541981}
#
#
# 2021-02-23 03:31:52 Training - Training image download completed. Training in progress.[2021-02-23 03:31:46.337] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6795, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5791407177028943, "sum": 0.5791407177028943, "min": 0.5791407177028943}}, "EndTime": 1614051106.337878, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.337776}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4759549259971734, "sum": 0.4759549259971734, "min": 0.4759549259971734}}, "EndTime": 1614051106.337978, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.337959}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4948354150206599, "sum": 0.4948354150206599, "min": 0.4948354150206599}}, "EndTime": 1614051106.338039, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338023}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5374999441789023, "sum": 0.5374999441789023, "min": 0.5374999441789023}}, "EndTime": 1614051106.338099, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338081}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6132990110579447, "sum": 0.6132990110579447, "min": 0.6132990110579447}}, "EndTime": 1614051106.338158, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338141}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.650242357378629, "sum": 0.650242357378629, "min": 0.650242357378629}}, "EndTime": 1614051106.338219, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338203}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6198758794314897, "sum": 0.6198758794314897, "min": 0.6198758794314897}}, "EndTime": 1614051106.338284, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338267}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.642763320194417, "sum": 0.642763320194417, "min": 0.642763320194417}}, "EndTime": 1614051106.338343, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338326}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4923872120919539, "sum": 0.4923872120919539, "min": 0.4923872120919539}}, "EndTime": 1614051106.338403, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338387}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5910773196579823, "sum": 0.5910773196579823, "min": 0.5910773196579823}}, "EndTime": 1614051106.338464, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338446}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5660034152850434, "sum": 0.5660034152850434, "min": 0.5660034152850434}}, "EndTime": 1614051106.338534, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338517}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.570866738247512, "sum": 0.570866738247512, "min": 0.570866738247512}}, "EndTime": 1614051106.338592, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338575}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.603102036327573, "sum": 0.603102036327573, "min": 0.603102036327573}}, "EndTime": 1614051106.338649, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338632}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6313092581015736, "sum": 0.6313092581015736, "min": 0.6313092581015736}}, "EndTime": 1614051106.338709, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338692}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6069122777967597, "sum": 0.6069122777967597, "min": 0.6069122777967597}}, "EndTime": 1614051106.338768, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338753}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6302709089116235, "sum": 0.6302709089116235, "min": 0.6302709089116235}}, "EndTime": 1614051106.338826, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.33881}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6274360078591198, "sum": 0.6274360078591198, "min": 0.6274360078591198}}, "EndTime": 1614051106.338884, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338867}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.512769868476906, "sum": 0.512769868476906, "min": 0.512769868476906}}, "EndTime": 1614051106.338943, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338926}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5364223231790054, "sum": 0.5364223231790054, "min": 0.5364223231790054}}, "EndTime": 1614051106.339, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.338984}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5448161246141596, "sum": 0.5448161246141596, "min": 0.5448161246141596}}, "EndTime": 1614051106.339059, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339042}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.540332931163922, "sum": 0.540332931163922, "min": 0.540332931163922}}, "EndTime": 1614051106.339118, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339101}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.541313360655128, "sum": 0.541313360655128, "min": 0.541313360655128}}, "EndTime": 1614051106.339175, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339159}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.536809625117623, "sum": 0.536809625117623, "min": 0.536809625117623}}, "EndTime": 1614051106.339233, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339217}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5356268091920632, "sum": 0.5356268091920632, "min": 0.5356268091920632}}, "EndTime": 1614051106.339291, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339276}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.081357410986819, "sum": 1.081357410986819, "min": 1.081357410986819}}, "EndTime": 1614051106.339351, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339333}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807654687315975, "sum": 1.0807654687315975, "min": 1.0807654687315975}}, "EndTime": 1614051106.339416, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339398}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.107846775994229, "sum": 1.107846775994229, "min": 1.107846775994229}}, "EndTime": 1614051106.339475, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339458}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0852037635688208, "sum": 1.0852037635688208, "min": 1.0852037635688208}}, "EndTime": 1614051106.339533, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339516}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2230319136423082, "sum": 1.2230319136423082, "min": 1.2230319136423082}}, "EndTime": 1614051106.339599, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339582}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.240264271721768, "sum": 1.240264271721768, "min": 1.240264271721768}}, "EndTime": 1614051106.339658, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339643}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2185808203615736, "sum": 1.2185808203615736, "min": 1.2185808203615736}}, "EndTime": 1614051106.339724, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339707}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2268015014801792, "sum": 1.2268015014801792, "min": 1.2268015014801792}}, "EndTime": 1614051106.33979, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051106.339774}
#
# [02/23/2021 03:31:46 INFO 140417266886464] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.579140717703
# [02/23/2021 03:31:46 INFO 140417266886464] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.475954925997
# [02/23/2021 03:31:46 INFO 140417266886464] Epoch 0: Loss improved. Updating best model
# [02/23/2021 03:31:46 INFO 140417266886464] Saving model for epoch: 0
# [02/23/2021 03:31:46 INFO 140417266886464] Saved checkpoint to "/tmp/tmpEYubHf/mx-mod-0000.params"
# [02/23/2021 03:31:46 INFO 140417266886464] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1614051106.353645, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1614051099.542239}
#
# [02/23/2021 03:31:46 INFO 140417266886464] #throughput_metric: host=algo-1, train throughput=29268.6636463 records/second
# [2021-02-23 03:31:53.580] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7225, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3762333395109704, "sum": 0.3762333395109704, "min": 0.3762333395109704}}, "EndTime": 1614051113.580962, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.580859}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3452077499849712, "sum": 0.3452077499849712, "min": 0.3452077499849712}}, "EndTime": 1614051113.581056, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581034}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3545212267391646, "sum": 0.3545212267391646, "min": 0.3545212267391646}}, "EndTime": 1614051113.581124, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581106}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.358282039009746, "sum": 0.358282039009746, "min": 0.358282039009746}}, "EndTime": 1614051113.581189, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58117}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.503855560801137, "sum": 0.503855560801137, "min": 0.503855560801137}}, "EndTime": 1614051113.581255, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581237}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5762882809279553, "sum": 0.5762882809279553, "min": 0.5762882809279553}}, "EndTime": 1614051113.581319, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581301}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5095617222809912, "sum": 0.5095617222809912, "min": 0.5095617222809912}}, "EndTime": 1614051113.581381, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581363}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5621733702846508, "sum": 0.5621733702846508, "min": 0.5621733702846508}}, "EndTime": 1614051113.581471, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58145}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.35608179332023887, "sum": 0.35608179332023887, "min": 0.35608179332023887}}, "EndTime": 1614051113.581545, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581525}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37639001955578677, "sum": 0.37639001955578677, "min": 0.37639001955578677}}, "EndTime": 1614051113.581627, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581609}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3734735677901225, "sum": 0.3734735677901225, "min": 0.3734735677901225}}, "EndTime": 1614051113.581698, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58168}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3714105723778806, "sum": 0.3714105723778806, "min": 0.3714105723778806}}, "EndTime": 1614051113.58176, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581743}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4968251642581806, "sum": 0.4968251642581806, "min": 0.4968251642581806}}, "EndTime": 1614051113.581829, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.581811}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5793348179342759, "sum": 0.5793348179342759, "min": 0.5793348179342759}}, "EndTime": 1614051113.581899, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58188}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5010429530119777, "sum": 0.5010429530119777, "min": 0.5010429530119777}}, "EndTime": 1614051113.581968, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58195}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5806286224671944, "sum": 0.5806286224671944, "min": 0.5806286224671944}}, "EndTime": 1614051113.582038, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58202}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45959482746986885, "sum": 0.45959482746986885, "min": 0.45959482746986885}}, "EndTime": 1614051113.582092, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582077}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45221469054869073, "sum": 0.45221469054869073, "min": 0.45221469054869073}}, "EndTime": 1614051113.582143, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582129}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4510753076447913, "sum": 0.4510753076447913, "min": 0.4510753076447913}}, "EndTime": 1614051113.582197, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582183}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45293791068379, "sum": 0.45293791068379, "min": 0.45293791068379}}, "EndTime": 1614051113.582248, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582235}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.513988640119083, "sum": 0.513988640119083, "min": 0.513988640119083}}, "EndTime": 1614051113.582298, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582283}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5301194904844965, "sum": 0.5301194904844965, "min": 0.5301194904844965}}, "EndTime": 1614051113.582352, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582337}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5141575448309357, "sum": 0.5141575448309357, "min": 0.5141575448309357}}, "EndTime": 1614051113.58241, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582392}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5306000879949062, "sum": 0.5306000879949062, "min": 0.5306000879949062}}, "EndTime": 1614051113.582465, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582449}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0809531622651833, "sum": 1.0809531622651833, "min": 1.0809531622651833}}, "EndTime": 1614051113.582534, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582515}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806157694294225, "sum": 1.0806157694294225, "min": 1.0806157694294225}}, "EndTime": 1614051113.582603, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582585}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0811927944164181, "sum": 1.0811927944164181, "min": 1.0811927944164181}}, "EndTime": 1614051113.582668, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.58265}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806420212942152, "sum": 1.0806420212942152, "min": 1.0806420212942152}}, "EndTime": 1614051113.582729, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582712}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1822309901558574, "sum": 1.1822309901558574, "min": 1.1822309901558574}}, "EndTime": 1614051113.582792, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582775}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2228483647485475, "sum": 1.2228483647485475, "min": 1.2228483647485475}}, "EndTime": 1614051113.582854, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582838}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1816888533549093, "sum": 1.1816888533549093, "min": 1.1816888533549093}}, "EndTime": 1614051113.582908, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582897}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2195927194566583, "sum": 1.2195927194566583, "min": 1.2195927194566583}}, "EndTime": 1614051113.582939, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1614051113.582931}
#
# [02/23/2021 03:31:53 INFO 140417266886464] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.376233339511
# [02/23/2021 03:31:53 INFO 140417266886464] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.345207749985
# [02/23/2021 03:31:53 INFO 140417266886464] Epoch 1: Loss improved. Updating best model
# [02/23/2021 03:31:53 INFO 140417266886464] Saving model for epoch: 1
# [02/23/2021 03:31:53 INFO 140417266886464] Saved checkpoint to "/tmp/tmpP2lcXx/mx-mod-0000.params"
# [02/23/2021 03:31:53 INFO 140417266886464] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max":

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5302559648638394, "sum": 0.5302559648638394, "min": 0.5302559648638394}}, "EndTime": 1614051120.183173, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183166}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5034230974091957, "sum": 0.5034230974091957, "min": 0.5034230974091957}}, "EndTime": 1614051120.183202, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183192}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.531876334511455, "sum": 0.531876334511455, "min": 0.531876334511455}}, "EndTime": 1614051120.183245, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183236}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080485231179089, "sum": 1.080485231179089, "min": 1.080485231179089}}, "EndTime": 1614051120.183273, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183266}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806065483668341, "sum": 1.0806065483668341, "min": 1.0806065483668341}}, "EndTime": 1614051120.183315, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.1833}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080347275623724, "sum": 1.080347275623724, "min": 1.080347275623724}}, "EndTime": 1614051120.183368, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183354}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807068119528305, "sum": 1.0807068119528305, "min": 1.0807068119528305}}, "EndTime": 1614051120.183422, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183407}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1454150128388525, "sum": 1.1454150128388525, "min": 1.1454150128388525}}, "EndTime": 1614051120.183493, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183473}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2139291877171503, "sum": 1.2139291877171503, "min": 1.2139291877171503}}, "EndTime": 1614051120.183557, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183539}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1451639179632291, "sum": 1.1451639179632291, "min": 1.1451639179632291}}, "EndTime": 1614051120.18362, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183604}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2131926508764526, "sum": 1.2131926508764526, "min": 1.2131926508764526}}, "EndTime": 1614051120.183678, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051120.183662}
#
# [02/23/2021 03:32:00 INFO 140417266886464] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.339114926976
# [02/23/2021 03:32:00 INFO 140417266886464] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.319540414705
# [02/23/2021 03:32:00 INFO 140417266886464] Epoch 2: Loss improved. Updating best model
# [02/23/2021 03:32:00 INFO 140417266886464] Saving model for epoch: 2
# [02/23/2021 03:32:00 INFO 140417266886464] Saved checkpoint to "/tmp/tmpYXT7F0/mx-mod-0000.params"
# [02/23/2021 03:32:00 INFO 140417266886464] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1614051120.191662, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1614051113.592221}
#
# [02/23/2021 03:32:00 INFO 140417266886464] #throughput_metric: host=algo-1, train throughput=30208.7776052 records/second
# [2021-02-23 03:32:07.870] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7677, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32226599174767884, "sum": 0.32226599174767884, "min": 0.32226599174767884}}, "EndTime": 1614051127.870721, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614051127.87062}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3074733453491824, "sum": 0.3074733453491824, "min": 0.3074733453491824}}, "EndTime": 1614051127.870822, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1614051127.870802}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2863595398946024, "sum": 0.2863595398946024, "min": 0.2863595398946024}}, "EndTime": 1614051202.251882, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.251867}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28373790798474796, "sum": 0.28373790798474796, "min": 0.28373790798474796}}, "EndTime": 1614051202.251934, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.25192}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5330752930856829, "sum": 0.5330752930856829, "min": 0.5330752930856829}}, "EndTime": 1614051202.251995, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.251978}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28378996158005604, "sum": 0.28378996158005604, "min": 0.28378996158005604}}, "EndTime": 1614051202.252056, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252039}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.47326236121019527, "sum": 0.47326236121019527, "min": 0.47326236121019527}}, "EndTime": 1614051202.252118, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252101}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29130650279749576, "sum": 0.29130650279749576, "min": 0.29130650279749576}}, "EndTime": 1614051202.252178, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252162}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29114658903955815, "sum": 0.29114658903955815, "min": 0.29114658903955815}}, "EndTime": 1614051202.25225, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252231}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29353761303005504, "sum": 0.29353761303005504, "min": 0.29353761303005504}}, "EndTime": 1614051202.252313, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252295}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2908794963204082, "sum": 0.2908794963204082, "min": 0.2908794963204082}}, "EndTime": 1614051202.252389, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252371}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2914942595515419, "sum": 0.2914942595515419, "min": 0.2914942595515419}}, "EndTime": 1614051202.252462, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252444}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4870187229367357, "sum": 0.4870187229367357, "min": 0.4870187229367357}}, "EndTime": 1614051202.25253, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252515}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2914134636116986, "sum": 0.2914134636116986, "min": 0.2914134636116986}}, "EndTime": 1614051202.252596, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252578}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.49398941992754913, "sum": 0.49398941992754913, "min": 0.49398941992754913}}, "EndTime": 1614051202.252667, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252649}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4376009713177705, "sum": 0.4376009713177705, "min": 0.4376009713177705}}, "EndTime": 1614051202.252729, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252712}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4484181482516342, "sum": 0.4484181482516342, "min": 0.4484181482516342}}, "EndTime": 1614051202.252797, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252779}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43762711445410646, "sum": 0.43762711445410646, "min": 0.43762711445410646}}, "EndTime": 1614051202.252867, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252848}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44841468803367424, "sum": 0.44841468803367424, "min": 0.44841468803367424}}, "EndTime": 1614051202.252929, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252911}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45202172866897966, "sum": 0.45202172866897966, "min": 0.45202172866897966}}, "EndTime": 1614051202.25299, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.252973}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5203195825893077, "sum": 0.5203195825893077, "min": 0.5203195825893077}}, "EndTime": 1614051202.253059, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.25304}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4520227471739803, "sum": 0.4520227471739803, "min": 0.4520227471739803}}, "EndTime": 1614051202.253127, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.25311}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5202868180394772, "sum": 0.5202868180394772, "min": 0.5202868180394772}}, "EndTime": 1614051202.253191, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253174}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0734474260339786, "sum": 1.0734474260339786, "min": 1.0734474260339786}}, "EndTime": 1614051202.253245, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253232}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0808105422743601, "sum": 1.0808105422743601, "min": 1.0808105422743601}}, "EndTime": 1614051202.253304, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253288}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.073446477075318, "sum": 1.073446477075318, "min": 1.073446477075318}}, "EndTime": 1614051202.253364, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253351}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0808158106204853, "sum": 1.0808158106204853, "min": 1.0808158106204853}}, "EndTime": 1614051202.253438, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253403}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.081110000226965, "sum": 1.081110000226965, "min": 1.081110000226965}}, "EndTime": 1614051202.253498, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253481}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.178819695554187, "sum": 1.178819695554187, "min": 1.178819695554187}}, "EndTime": 1614051202.253568, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.253549}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0811094335814817, "sum": 1.0811094335814817, "min": 1.0811094335814817}}, "EndTime": 1614051202.253638, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.25362}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1788132949905779, "sum": 1.1788132949905779, "min": 1.1788132949905779}}, "EndTime": 1614051202.253697, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051202.25368}
#
# [02/23/2021 03:33:22 INFO 140417266886464] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.290683084536
# [02/23/2021 03:33:22 INFO 140417266886464] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.283737907985
# [02/23/2021 03:33:22 INFO 140417266886464] Epoch 14: Loss improved. Updating best model
# [02/23/2021 03:33:22 INFO 140417266886464] Saving model for epoch: 14
# [02/23/2021 03:33:22 INFO 140417266886464] Saved checkpoint to "/tmp/tmpr6tv5O/mx-mod-0000.params"
# [02/23/2021 03:33:22 INFO 140417266886464] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1614051202.261782, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1614051196.185204}
#
# [02/23/2021 03:33:22 INFO 140417266886464] #throughput_metric: host=algo-1, train throughput=32808.0622428 records/second
# [02/23/2021 03:33:22 WARNING 140417266886464] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/23/2021 03:33:22 WARNING 140417266886464] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-23 03:33:22.269] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-02-23 03:33:22.897] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 625, "num_examples": 200, "num_bytes": 33493152}
# [2021-02-23 03:33:23.607] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 635, "num_examples": 200, "num_bytes": 33493152}
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/23/2021 03:33:23 INFO 140417266886464] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.268748395743
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.991317389298
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.271771140093
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train precision <score>=0.159900990099
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train recall <score>=0.904761904762
# [02/23/2021 03:33:23 INFO 140417266886464] #quality_metric: host=algo-1, train roc_auc_score <score>=0.988334714913
# [02/23/2021 03:33:23 INFO 140417266886464] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/23/2021 03:33:23 INFO 140417266886464] Saved checkpoint to "/tmp/tmp3pVRjR/mx-mod-0000.params"
# [02/23/2021 03:33:23 INFO 140417266886464] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 104706.59923553467, "sum": 104706.59923553467, "min": 104706.59923553467}, "finalize.time": {"count": 1, "max": 1404.6409130096436, "sum": 1404.6409130096436, "min": 1404.6409130096436}, "initialize.time": {"count": 1, "max": 328.7951946258545, "sum": 328.7951946258545, "min": 328.7951946258545}, "check_early_stopping.time": {"count": 15, "max": 1.1510848999023438, "sum": 13.456106185913086, "min": 0.8301734924316406}, "setuptime": {"count": 1, "max": 31.962156295776367, "sum": 31.962156295776367, "min": 31.962156295776367}, "update.time": {"count": 15, "max": 7685.065984725952, "sum": 102657.390832901, "min": 6074.102878570557}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1614051203.677977, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1614051099.209033}
#
#
# 2021-02-23 03:33:54 Completed - Training job completed
# ProfilerReport-1614050906: NoIssuesFound
# Training seconds: 148
# Billable seconds: 148

# %%
balanced=linear_balanced.deploy(instance_type='ml.t2.medium',initial_instance_count=1)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------------!

# %%
evaluation_metrics(test_record,test_y,balanced)
# Out:
# {'TP': 117,
#  'FP': 679,
#  'FN': 18,
#  'TN': 84629,
#  'Precision': 0.14698492462311558,
#  'Recall': 0.8666666666666667,
#  'Accuracy': 0.9918425148929696}
